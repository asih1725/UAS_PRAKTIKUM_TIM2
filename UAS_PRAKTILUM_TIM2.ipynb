# %% [markdown]
# <a href="https://colab.research.google.com/github/asih1725/UAS_PRAKTIKUM_TIM2/blob/main/UAS_PRAKTILUM_TIM2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Mahasiswa:
    def __init__(self, nama, nim, nilai_akhir):
        self.nama = nama
        self.nim = nim
        self.nilai_akhir = nilai_akhir

    def tambah_nilai(self, nilai):
        try:
            self.nilai_akhir += float(nilai)
        except ValueError:
            print("Error: Nilai yang dimasukkan bukan angka.")

    def info_mahasiswa(self):
        print(f"Nama: {self.nama}, NIM: {self.nim}, Nilai Akhir: {self.nilai_akhir}")


daftar_mahasiswa = []

def tambah_mahasiswa():
    nama = input("Masukkan nama mahasiswa: ")
    nim = input("Masukkan NIM mahasiswa: ")
    try:
        nilai_akhir = float(input("Masukkan nilai akhir mahasiswa: "))
        mahasiswa_baru = Mahasiswa(nama, nim, nilai_akhir)
        daftar_mahasiswa.append(mahasiswa_baru)
        print("Mahasiswa berhasil ditambahkan.")
    except ValueError:
        print("Error: Nilai akhir harus berupa angka.")

def update_nilai():
    nim = input("Masukkan NIM mahasiswa yang ingin diupdate nilainya: ")
    for mhs in daftar_mahasiswa:
        if mhs.nim == nim:
            try:
                nilai_baru = float(input("Masukkan nilai baru: "))
                mhs.nilai_akhir = nilai_baru
                print("Nilai berhasil diupdate.")
                return
            except ValueError:
                print("Error: Nilai baru harus berupa angka.")
    print(f"Mahasiswa dengan NIM {nim} tidak ditemukan.")

def tampilkan_semua_mahasiswa():
    if not daftar_mahasiswa:
        print("Belum ada data mahasiswa.")
        return
    for mhs in daftar_mahasiswa:
        mhs.info_mahasiswa()

def cari_mahasiswa(nim):
    for mhs in daftar_mahasiswa:
        if mhs.nim == nim:
            mhs.info_mahasiswa()
            return
    print(f"Mahasiswa dengan NIM {nim} tidak ditemukan.")

while True:
    print("\nMenu:")
    print("1. Tambah Mahasiswa")
    print("2. Update Nilai")
    print("3. Tampilkan Semua Mahasiswa")
    print("4. Cari Mahasiswa")
    print("5. Keluar")

    pilihan = input("Masukkan pilihan Anda (1-5): ")

    if pilihan == '1':
        tambah_mahasiswa()
    elif pilihan == '2':
        update_nilai()
    elif pilihan == '3':
        tampilkan_semua_mahasiswa()
    elif pilihan == '4':
        nim = input("Masukkan NIM mahasiswa yang ingin dicari: ")
        cari_mahasiswa(nim)
    elif pilihan == '5':
        break
    else:
        print("Pilihan tidak valid.")
# Out:
# Menu:
# 1. Tambah Mahasiswa
# 2. Update Nilai
# 3. Tampilkan Semua Mahasiswa
# 4. Cari Mahasiswa
# 5. Keluar
# Masukkan pilihan Anda (1-5): 1
# Masukkan nama mahasiswa: ABS
# Masukkan NIM mahasiswa: 12234
# Masukkan nilai akhir mahasiswa: 90
# Mahasiswa berhasil ditambahkan.
#
# Menu:
# 1. Tambah Mahasiswa
# 2. Update Nilai
# 3. Tampilkan Semua Mahasiswa
# 4. Cari Mahasiswa
# 5. Keluar
# Masukkan pilihan Anda (1-5): 2
# Masukkan NIM mahasiswa yang ingin diupdate nilainya: 12345
# Mahasiswa dengan NIM 12345 tidak ditemukan.
#
# Menu:
# 1. Tambah Mahasiswa
# 2. Update Nilai
# 3. Tampilkan Semua Mahasiswa
# 4. Cari Mahasiswa
# 5. Keluar
# Masukkan pilihan Anda (1-5): 3
# Nama: ABS, NIM: 12234, Nilai Akhir: 90.0
#
# Menu:
# 1. Tambah Mahasiswa
# 2. Update Nilai
# 3. Tampilkan Semua Mahasiswa
# 4. Cari Mahasiswa
# 5. Keluar
# Masukkan pilihan Anda (1-5): 4
# Masukkan NIM mahasiswa yang ingin dicari: 1234
# Mahasiswa dengan NIM 1234 tidak ditemukan.
#
# Menu:
# 1. Tambah Mahasiswa
# 2. Update Nilai
# 3. Tampilkan Semua Mahasiswa
# 4. Cari Mahasiswa
# 5. Keluar
# Masukkan pilihan Anda (1-5): 5
